# %% [markdown]
# ## 概要
#
# - Web of Science からダウンロードしたタブ区切りの`txt` ファイルを、`csv` ファイルに変換するスクリプト
# - 入力：`data/raw_data`内の`txt`ファイルを入力
# - 出力：`data/csv`フォルダに`csv`ファイルとして出力
# - データの前処理も行う（Publication Type, Authors, Title, Abstract, DOI）

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# 入力ファイルと出力ファイルのパスを指定
file_name = "Biochemistry_Molecular_Biology_low1000"  # ファイル名
input_file = f"../data/raw_data/{file_name}.txt"  # タブ区切りの.txtファイル
output_file = f"../data/csv/{file_name}.csv"  # 出力する.csvファイル

# タブ区切りの.txtファイルをDataFrameとして読み込む
try:
    df = pd.read_csv(input_file, sep="\t", encoding="utf-8")
    print("データの読み込みに成功しました。")
except Exception as e:
    print(f"エラーが発生しました: {e}")
# Out:
# データの読み込みに成功しました。

# %%
df.head()
# Out:
#   PT                            AU   BA         BE  GP  \
# 0  J         Athare, SV; Gejji, SP  NaN        NaN NaN
# 1  J      Brunetti, M; Mortola, JP  NaN        NaN NaN
# 2  J    Du, ZF; Qu, Y; Farrell, NP  NaN        NaN NaN
# 3  B             Jahn, D; Geier, A  NaN  Patel, VB NaN
# 4  J  Pakravan, M; Shamsollahi, MB  NaN        NaN NaN
#
#                                                   AF   BF   CA  \
# 0          Athare, Sulakshana, V; Gejji, Shridhar P.  NaN  NaN
# 1                  Brunetti, Mia; Mortola, Jacopo P.  NaN  NaN
# 2         Du, Zhifeng; Qu, Yun; Farrell, Nicholas P.  NaN  NaN
# 3                       Jahn, Daniel; Geier, Andreas  NaN  NaN
# 4  Pakravan, Mansooreh; Shamsollahi, Mohammad Bagher  NaN  NaN
#
#                                                   TI  \
# 0  Regioselectivity in nonsymmetric methyl pentyl...
# 1  Hypoxic hypometabolism in chicken embryos: con...
# 2  Intramolecular platinum migration on a peptide...
# 3  Transcriptional control of cells by vitamin D ...
# 4  Spatial and temporal joint, partially-joint an...
#
#                                                   SO  ...  WC  WE  SC  GA  \
# 0          JOURNAL OF MOLECULAR GRAPHICS & MODELLING  ... NaN NaN NaN NaN
# 1  COMPARATIVE BIOCHEMISTRY AND PHYSIOLOGY A-MOLE...  ... NaN NaN NaN NaN
# 2                  JOURNAL OF INORGANIC BIOCHEMISTRY  ... NaN NaN NaN NaN
# 3                      MOLECULAR NUTRITION: VITAMINS  ... NaN NaN NaN NaN
# 4                    JOURNAL OF NEUROSCIENCE METHODS  ... NaN NaN NaN NaN
#
#            PM  OA  HC  HP  DA                   UT
# 0  31593920.0 NaN NaN NaN NaN  WOS:000503098000004
# 1  31521704.0 NaN NaN NaN NaN  WOS:000498317300002
# 2  31689625.0 NaN NaN NaN NaN  WOS:000502686300017
# 3         NaN NaN NaN NaN NaN  WOS:000487827500033
# 4  31644994.0 NaN NaN NaN NaN  WOS:000499768800004
#
# [5 rows x 71 columns]

# %%
# 列名を変更（例: "旧列名1" を "新列名1" に変更）
columns_to_rename = {
    "PT": "Publication Type",
    "AU": "Authors",
    "TI": "Title",
    "SO": "Source",
    "AB": "Abstract",
    "DI": "DOI",
}  # 変更したい列名を辞書形式で指定
try:
    df = df.rename(columns=columns_to_rename)
    print("列名を変更しました。")
except Exception as e:
    print(f"エラーが発生しました: {e}")
# Out:
# 列名を変更しました。

# %%
# 保持したい列を指定（例: "列名1", "列名2" のみ保持）
columns_to_keep = ["Publication Type", "Authors", "Title", "Abstract", "DOI"]  # 保持したい列名をリストで指定
try:
    df = df[columns_to_keep]  # 指定した列以外を削除
    print(f"指定した列 {columns_to_keep} 以外を削除しました。")
except KeyError as e:
    print(f"指定した列が存在しません: {e}")
# Out:
# 指定した列 ['Publication Type', 'Authors', 'Title', 'Abstract', 'DOI'] 以外を削除しました。

# %%
df.head()
# Out:
#   Publication Type                       Authors  \
# 0                J         Athare, SV; Gejji, SP
# 1                J      Brunetti, M; Mortola, JP
# 2                J    Du, ZF; Qu, Y; Farrell, NP
# 3                B             Jahn, D; Geier, A
# 4                J  Pakravan, M; Shamsollahi, MB
#
#                                                Title  \
# 0  Regioselectivity in nonsymmetric methyl pentyl...
# 1  Hypoxic hypometabolism in chicken embryos: con...
# 2  Intramolecular platinum migration on a peptide...
# 3  Transcriptional control of cells by vitamin D ...
# 4  Spatial and temporal joint, partially-joint an...
#
#                                             Abstract  \
# 0  The present work illustrates regioselective bi...
# 1  Postnatally, during hypoxia the decrease in ox...
# 2  We report the migration of platinum ligand uni...
# 3                                                NaN
# 4  absectionBackground Three types of sources can...
#
#                                   DOI
# 0          10.1016/j.jmgm.2019.107960
# 1          10.1016/j.cbpa.2019.110578
# 2     10.1016/j.jinorgbio.2019.110858
# 3  10.1016/B978-0-12-811907-5.00030-0
# 4      10.1016/j.jneumeth.2019.108453

# %%
# CSVファイルとしてエクスポート
try:
    df.to_csv(output_file, index=False, encoding="utf-8-sig")
    print(f"CSVファイルとして保存しました: {output_file}")
except Exception as e:
    print(f"エラーが発生しました: {e}")
# Out:
# CSVファイルとして保存しました: ../data/csv/Biochemistry_Molecular_Biology_low1000.csv
