# %% [markdown]
# ## 概要
#
# - Web of Science からダウンロードしたタブ区切りの`txt` ファイルを、`csv` ファイルに変換するスクリプト
# - 入力：`data/raw_data`内の`txt`ファイルを入力
# - 出力：`data/csv`フォルダに`csv`ファイルとして出力
# - データの前処理も行う（Publication Type, Authors, Title, Abstract, DOI）

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /Volumes/Macintosh HD - Data 1/Users/quandomac1/Project/PTL1/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# 入力ファイルと出力ファイルのパスを指定
file_name = "Physics_low1000"  # ファイル名
input_file = f"../data/raw_data/{file_name}.txt"  # タブ区切りの.txtファイル
output_file = f"../data/csv/{file_name}.csv"  # 出力する.csvファイル

# タブ区切りの.txtファイルをDataFrameとして読み込む
try:
    df = pd.read_csv(input_file, sep="\t", encoding="utf-8")
    print("データの読み込みに成功しました。")
except Exception as e:
    print(f"エラーが発生しました: {e}")
# Out:
# データの読み込みに成功しました。

# %%
df.head()
# Out:
#   PT                                                 AU   BA  BE  GP  \
# 0  J                                        Hossain, MF  NaN NaN NaN
# 1  J                                             Li, KD  NaN NaN NaN
# 2  J  Oguma, H; Seitoku, E; Mutoh, M; Yoshizawa, S; ...  NaN NaN NaN
# 3  J                  Shakya, J; Kasana, PK; Mohanty, T  NaN NaN NaN
# 4  J  Vathani, AM; Dhanalakshmi, S; Jeyakumaran, N; ...  NaN NaN NaN
#
#                                                   AF   BF   CA  \
# 0                                     Hossain, M. F.  NaN  NaN
# 1                                        Li, Kun-Dar  NaN  NaN
# 2  Oguma, Hidetoshi; Seitoku, Eri; Mutoh, Mami; Y...  NaN  NaN
# 3          Shakya, Jyoti; Kasana, P. K.; Mohanty, T.  NaN  NaN
# 4  Vathani, A. Mathi; Dhanalakshmi, S.; Jeyakumar...  NaN  NaN
#
#                                                   TI  \
# 0  Fabrication of Nanosticks-Like CdS Sensitizer ...
# 1  The Influence of Process Parameters on the Mor...
# 2  Size- and Morphology-Controlled Preparation of...
# 3  Investigation of Swift Heavy Ion Irradiated Re...
# 4  Fabrication of Al-TiO<sub>2</sub> Thin Film El...
#
#                                           SO  ...  WC  WE  SC  GA          PM  \
# 0  JOURNAL OF NANOSCIENCE AND NANOTECHNOLOGY  ... NaN NaN NaN NaN  31635638.0
# 1  JOURNAL OF NANOSCIENCE AND NANOTECHNOLOGY  ... NaN NaN NaN NaN  31635649.0
# 2  JOURNAL OF NANOSCIENCE AND NANOTECHNOLOGY  ... NaN NaN NaN NaN  31635601.0
# 3  JOURNAL OF NANOSCIENCE AND NANOTECHNOLOGY  ... NaN NaN NaN NaN  31635662.0
# 4  JOURNAL OF NANOSCIENCE AND NANOTECHNOLOGY  ... NaN NaN NaN NaN  31635625.0
#
#    OA  HC  HP  DA                   UT
# 0 NaN NaN NaN NaN  WOS:000492366900040
# 1 NaN NaN NaN NaN  WOS:000492366900051
# 2 NaN NaN NaN NaN  WOS:000492366900003
# 3 NaN NaN NaN NaN  WOS:000492366900064
# 4 NaN NaN NaN NaN  WOS:000492366900027
#
# [5 rows x 71 columns]

# %%
# 列名を変更（例: "旧列名1" を "新列名1" に変更）
columns_to_rename = {
    "PT": "Publication Type",
    "AU": "Authors",
    "TI": "Title",
    "SO": "Source",
    "AB": "Abstract",
    "DI": "DOI",
}  # 変更したい列名を辞書形式で指定
try:
    df = df.rename(columns=columns_to_rename)
    print("列名を変更しました。")
except Exception as e:
    print(f"エラーが発生しました: {e}")
# Out:
# 列名を変更しました。

# %%
# 保持したい列を指定（例: "列名1", "列名2" のみ保持）
columns_to_keep = ["Publication Type", "Authors", "Title", "Abstract", "DOI"]  # 保持したい列名をリストで指定
try:
    df = df[columns_to_keep]  # 指定した列以外を削除
    print(f"指定した列 {columns_to_keep} 以外を削除しました。")
except KeyError as e:
    print(f"指定した列が存在しません: {e}")
# Out:
# 指定した列 ['Publication Type', 'Authors', 'Title', 'Abstract', 'DOI'] 以外を削除しました。

# %%
df.head()
# Out:
#   Publication Type                                            Authors  \
# 0                J                                        Hossain, MF
# 1                J                                             Li, KD
# 2                J  Oguma, H; Seitoku, E; Mutoh, M; Yoshizawa, S; ...
# 3                J                  Shakya, J; Kasana, PK; Mohanty, T
# 4                J  Vathani, AM; Dhanalakshmi, S; Jeyakumaran, N; ...
#
#                                                Title  \
# 0  Fabrication of Nanosticks-Like CdS Sensitizer ...
# 1  The Influence of Process Parameters on the Mor...
# 2  Size- and Morphology-Controlled Preparation of...
# 3  Investigation of Swift Heavy Ion Irradiated Re...
# 4  Fabrication of Al-TiO<sub>2</sub> Thin Film El...
#
#                                             Abstract                     DOI
# 0  The novelty of this work is to fabricate the N...  10.1166/jnn.2020.17477
# 1  In nanoarchitectonics, the advanced technology...  10.1166/jnn.2020.17429
# 2  In this study, we investigated water-dispersib...  10.1166/jnn.2020.17473
# 3  In this work, a few layer molybdenum disulfide...  10.1166/jnn.2020.17400
# 4  A simple cost effective Al-TiO2 thin film elec...  10.1166/jnn.2020.17447

# %%
# CSVファイルとしてエクスポート
try:
    df.to_csv(output_file, index=False, encoding="utf-8-sig")
    print(f"CSVファイルとして保存しました: {output_file}")
except Exception as e:
    print(f"エラーが発生しました: {e}")
# Out:
# CSVファイルとして保存しました: ../data/csv/Physics_low1000.csv
